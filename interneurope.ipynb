# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
os.getcwd()
# Out:
# '/Users/jatinjaglan'

# %%
os.listdir()
# Out:
# ['Music',
#  'Untitled1.ipynb',
#  '.DS_Store',
#  '.CFUserTextEncoding',
#  'Untitled.ipynb',
#  'Pictures',
#  '.zprofile',
#  '.zsh_history',
#  '.ipython',
#  'Desktop',
#  'Library',
#  '.matplotlib',
#  'Public',
#  'payroll_fraud_risk_management_project.ipynb',
#  '.idlerc',
#  'Movies',
#  'Applications',
#  '.Trash',
#  '.ipynb_checkpoints',
#  '.jupyter',
#  'Documents',
#  'Downloads',
#  '.zsh_sessions']

# %%
df=pd.read_csv('/Users/jatinjaglan/Downloads/European_bank.csv')

# %%
df.head()
# Out:
#    Year  CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0  2025    15634602  Hargrave          619    France  Female   42       2
# 1  2025    15647311      Hill          608     Spain  Female   41       1
# 2  2025    15619304      Onio          502    France  Female   42       8
# 3  2025    15701354      Boni          699    France  Female   39       1
# 4  2025    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.columns
# Out:
# Index(['Year', 'CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender',
#        'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  str
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  str
#  5   Gender           10000 non-null  str
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), str(3)
# memory usage: 1.1 MB

# %%
df.describe()
# Out:
#           Year    CustomerId   CreditScore           Age        Tenure  \
# count  10000.0  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    2025.0  1.569094e+07    650.528800     38.921800      5.012800
# std        0.0  7.193619e+04     96.653299     10.487806      2.892174
# min     2025.0  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2025.0  1.562853e+07    584.000000     32.000000      3.000000
# 50%     2025.0  1.569074e+07    652.000000     37.000000      5.000000
# 75%     2025.0  1.575323e+07    718.000000     44.000000      7.000000
# max     2025.0  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Year               0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Exited"].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
df["Exited"].value_counts(normalize=True)*100
# Out:
# Exited
# 0    79.63
# 1    20.37
# Name: proportion, dtype: float64

# %%
df["IsActiveMember"].value_counts()
# Out:
# IsActiveMember
# 1    5151
# 0    4849
# Name: count, dtype: int64

# %%
df["NumOfProducts"].value_counts()
# Out:
# NumOfProducts
# 1    5084
# 2    4590
# 3     266
# 4      60
# Name: count, dtype: int64

# %%
df.groupby("IsActiveMember")["Exited"].mean()*100
# Out:
# IsActiveMember
# 0    26.850897
# 1    14.269074
# Name: Exited, dtype: float64

# %%
df.groupby("NumOfProducts")["Exited"].mean()*100
# Out:
# NumOfProducts
# 1     27.714398
# 2      7.581699
# 3     82.706767
# 4    100.000000
# Name: Exited, dtype: float64

# %%
df[(df["Balance"]> 100000) & (df["IsActiveMember"]== 0 )]
# Out:
#       Year  CustomerId  Surname  CreditScore Geography  Gender  Age  Tenure  \
# 2     2025    15619304     Onio          502    France  Female   42       8
# 5     2025    15574012      Chu          645     Spain    Male   44       8
# 7     2025    15656148   Obinna          376   Germany  Female   29       4
# 10    2025    15767821   Bearce          528    France    Male   31       6
# 16    2025    15737452    Romeo          653   Germany    Male   58       1
# ...    ...         ...      ...          ...       ...     ...  ...     ...
# 9976  2025    15656062  Azikiwe          637    France  Female   33       7
# 9982  2025    15768163  Griffin          655   Germany  Female   46       7
# 9985  2025    15586914   Nepean          659    France    Male   36       6
# 9993  2025    15569266   Rahman          644    France    Male   28       7
# 9999  2025    15628319   Walker          792    France  Female   28       4
#
# ...

# %%
df[(df["Balance"]> 100000) & (df["IsActiveMember"]== 0 )]["Exited"].mean()*100
# Out:
# np.float64(32.76740237691001)

# %%
def classify_customer (row) :
           if row ["IsActiveMember"]==1 and row ["NumOfProducts"] >= 2:
              return "actively engaged"

           elif row["IsActiveMember"]==0 and row ["NumOfProducts"] <= 1:
                return "Inactive Disengaged"

           elif row["IsActiveMember"]==1 and row ["NumOfProducts"] ==1:
                return "Active Low Product"
 
           elif row ["IsActiveMember"]==0 and row ["Balance"]> 100000:
                return "Inactive High Balance"

           else:
                return"others"
df["Customersegment"]= df.apply(classify_customer, axis=1)

# %%
df["Customersegment"].value_counts()
# Out:
# Customersegment
# actively engaged         2588
# Active Low Product       2563
# Inactive Disengaged      2521
# others                   1549
# Inactive High Balance     779
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Year  CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0  2025    15634602  Hargrave          619    France  Female   42       2
# 1  2025    15647311      Hill          608     Spain  Female   41       1
# 2  2025    15619304      Onio          502    France  Female   42       8
# 3  2025    15701354      Boni          699    France  Female   39       1
# 4  2025    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited        Customersegment
# 0       1     Active Low Product
# ...

# %%
df.groupby("Customersegment")["Exited"].mean()*100
# Out:
# Customersegment
# Active Low Product       18.923137
# Inactive Disengaged      36.652122
# Inactive High Balance    27.599487
# actively engaged          9.659969
# others                   10.522918
# Name: Exited, dtype: float64

# %%
df["Customersegment"].value_counts().plot(kind="bar")
plt.title("Customer Segmentation Distribution")
plt.xlabel("Customersegment")
plt.ylabel("Number Of Customers")
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.groupby("Customersegment")["Exited"].mean().plot(kind="bar")
plt.title("Churn Rate By Customer Segment")
plt.xlabel("Customersegment")
plt.ylabel("Churn Rate")
plt.xticks(rotation=45)
plt.show()

# %%
engagement_kpi=df.groupby("IsActiveMember")["Exited"].mean()*100
engagement_kpi
# Out:
# IsActiveMember
# 0    26.850897
# 1    14.269074
# Name: Exited, dtype: float64

# %%
product_kpi=df.groupby("Exited")["NumOfProducts"].mean()
product_kpi
# Out:
# Exited
# 0    1.544267
# 1    1.475209
# Name: NumOfProducts, dtype: float64

# %%
high_balance_kpi=df[(df["Balance"]>100000)&(df["IsActiveMember"]==0)]["Exited"].mean()*100
high_balance_kpi
# Out:
# np.float64(32.76740237691001)

# %%
card_kpi = df.groupby('HasCrCard')['Exited'].mean()*100
card_kpi
# Out:
# HasCrCard
# 0    20.814941
# 1    20.184266
# Name: Exited, dtype: float64

# %%
df["RelationshipScore"]=df["IsActiveMember"] + df["NumOfProducts"]

relationship_kpi=df.groupby("RelationshipScore")["Exited"].mean()*100
relationship_kpi
# Out:
# RelationshipScore
# 1     36.652122
# 2     14.807733
# 3     10.427087
# 4     80.555556
# 5    100.000000
# Name: Exited, dtype: float64
